# %% [markdown]
# # Quest 150 · Image_GS_Adaptive_Image_Reconstruction_using_2D_Gaussians
#
# 이 노트북은 CV Quest가 저장소의 기존 학습 자료를 실행 가능하게 연결한 래퍼입니다. 위에서 아래 순서로 셀을 실행하세요. 모델·데이터·GPU가 필요한 프로젝트는 README 요구사항을 먼저 확인해야 합니다.
#
# ## 출처
# 이 저장소의 프로젝트 README와 원본 소스 코드
#
# ## 프로젝트 안내
# # Image-GS: Adaptive Image Reconstruction using 2D Gaussians
#
# This repository contains a README file having all the instructions and terminal commands in the exact order in which they have to be executed on the terminal to run the Image-GS Image Reconstruction Pipeline using 2D Gaussians. It contains a python script (model.py) which has to be replaced with the original python script, got cloned into the system while cloning the Image-GS repository. Because of some updates in the file sturucture, few imports are wrong, alongwith some script names, too, which is why, the replacement of the model.py python script is necessary.
#
#
# It is part of the LearnOpenCV blog post - [Image-GS: Adaptive Image Reconstruction using 2D Gaussians](https://learnopencv.com/image-gs-image-reconstruction-using-2d-gaussians/).
#
# [](https://www.dropbox.com/scl/fo/lkrkyotwg4kan8n9z802l/AE5OSzC1cwmRWAzyhab14vk?rlkey=jek9etd2t7y5sj98s43rekyvr&st=makot1fm&dl=1)
#
# ![](https://learnopencv.com/wp-content/uploads/2025/11/Image-GS_Image_Reconstruction_using_2D_Gaussians.jpg)
#
#
# ---
#
#
#
#
#
#
#
# Build Production-Ready Computer Vision &amp; AI Solutions
#
#
#   LearnOpenCV is maintained by BigVision.AI, a computer vision and AI consulting company. We help organizations design, build, optimize, and deploy production-ready AI solutions. Our team has deep expertise in computer vision, deep learning, multimodal AI, and edge deployment, with experience solving complex technical challenges across industries.
#
#
#
#   Have a project in mind? Talk with our expert AI solution builders.

# %%
from pathlib import Path

here = Path.cwd().resolve()
ROOT = next(p for p in [here, *here.parents] if (p / "learnopencv_progression.py").exists())
PROJECT = ROOT / 'Image_GS_Adaptive_Image_Reconstruction_using_2D_Gaussians'
SOURCE = PROJECT / 'model.py'
print("Repository:", ROOT)
print("Project:", PROJECT)
print("Source:", SOURCE if SOURCE else "starter example")

# %% [markdown]
# ## 대표 Python 소스 미리보기

# %%
code = SOURCE.read_text(encoding='utf-8', errors='replace')
print(code[:12000])
print(f'\n--- {len(code)} characters total ---')

# %% [markdown]
# ## 실행
# 아래 셀은 원본 스크립트를 프로젝트 폴더에서 실행합니다. 웹캠·GUI·모델 다운로드를 사용하는 예제는 중지 버튼으로 종료할 수 있습니다.

# %%
import os, runpy
previous = Path.cwd()
os.chdir(PROJECT)
try:
    runpy.run_path(str(SOURCE), run_name='__main__')
finally:
    os.chdir(previous)

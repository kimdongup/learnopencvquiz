# %% [markdown]
# # YOLOv5 Instance Segmentation
#
# This notebook is for running inference on images using the YOLOv5 instance segmentation models. Mainly, we use two models, `yolov5n-seg` and `yolovx-seg`.
#
# Along with that, also use `--retina-masks` flag to get outputs on native resolution images.

# %%
import matplotlib.pyplot as plt
import os
import glob
import requests
import zipfile

# %% [markdown]
# ## Download Data

# %%
def download_file(url, save_name):
    url = url
    if not os.path.exists(save_name):
        file = requests.get(url)
        open(save_name, 'wb').write(file.content)
        
download_file(
    'https://www.dropbox.com/s/80y1ebk254d2ypg/images.zip?dl=1',
    'images.zip'
)

# %%
# Unzip the data file
def unzip(zip_file=None):
    try:
        with zipfile.ZipFile(zip_file) as z:
            z.extractall("./")
            print("Extracted all")
    except:
        print("Invalid file")

unzip('images.zip')
# Out:
# Extracted all

# %% [markdown]
# ## Clone the YOLOv5 Repository

# %%
if not os.path.exists('yolov5'):
    # !git clone https://github.com/ultralytics/yolov5.git

# %%
# %cd yolov5/
# Out:
# /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: gitpython in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (3.1.29)
# Requirement already satisfied: ipython in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (8.7.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (3.6.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.23.5)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (4.6.0.66)
# Requirement already satisfied: Pillow>=7.1.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (9.3.0)
# Requirement already satisfied: psutil in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (5.9.4)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (1.9.3)
# Requirement already satisfied: thop>=0.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.12.0+cu116)
# Requirement already satisfied: torchvision>=0.8.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (0.13.0+cu116)
# Requirement already satisfied: tqdm>=4.64.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (4.64.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (2.11.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (1.5.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from gitpython->-r requirements.txt (line 5)) (4.0.10)
# Requirement already satisfied: stack-data in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: pickleshare in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: pexpect>4.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (2.13.0)
# Requirement already satisfied: backcall in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (5.6.0)
# Requirement already satisfied: decorator in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->-r requirements.txt (line 6)) (3.0.36)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 7)) (4.38.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->-r requirements.txt (line 13)) (2.1.1)
# Requirement already satisfied: typing-extensions in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from torch>=1.7.0->-r requirements.txt (line 16)) (4.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.2.2)
# Requirement already satisfied: grpcio>=1.24.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.51.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.4.1)
# Requirement already satisfied: absl-py>=0.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.6)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.20.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.37.1)
# Requirement already satisfied: pytz>=2020.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2022.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->-r requirements.txt (line 5)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 22)) (5.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (2.1.1)
# Requirement already satisfied: pure-eval in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 22)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->-r requirements.txt (line 22)) (3.2.2)

# %% [markdown]
# ## Inference on Images

# %% [markdown]
# ### Using YOLOv5 Nano Segmentation Model

# %%
# !python segment/predict.py --weights yolov5n-seg.pt --source images/ --name yolov5n_seg --exist-ok
# Out:
# segment/predict: weights=['yolov5n-seg.pt'], source=images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=yolov5n_seg, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-49-g3c1afd9 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
#
# Fusing layers...
# YOLOv5n-seg summary: 224 layers, 1986637 parameters, 0 gradients, 7.1 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_1.jpg: 448x640 19 persons, 9.1ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_2.jpg: 384x640 20 persons, 6 cars, 3 buss, 1 truck, 1 traffic light, 8.5ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_3.jpg: 384x640 2 persons, 1 skis, 6.5ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_4.jpg: 448x640 13 persons, 5 cars, 4 traffic lights, 7.1ms
# Speed: 0.3ms pre-process, 7.8ms inference, 0.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/yolov5n_seg

# %% [markdown]
# ## Visualize Images

# %%
# Plot and visualize images in a 2x2 grid.
def visualize(result_dir):
    """
    Function accepts a list of images and plots
    them in a 2x2 grid.
    """
    plt.figure(figsize=(20, 12))
    image_names = glob.glob(os.path.join(result_dir, '*.jpg'))
    for i, image_name in enumerate(image_names):
        image = plt.imread(image_name)
        plt.subplot(2, 2, i+1)
        plt.imshow(image)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
visualize('runs/predict-seg/yolov5n_seg/')

# %% [markdown]
# ### Using YOLOv5X Segmentation Model

# %%
# !python segment/predict.py --weights yolov5x-seg.pt --source images/ --name yolov5x_seg --exist-ok
# Out:
# segment/predict: weights=['yolov5x-seg.pt'], source=images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=yolov5x_seg, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-49-g3c1afd9 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
#
# Fusing layers...
# YOLOv5x-seg summary: 455 layers, 88774445 parameters, 0 gradients, 265.7 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_1.jpg: 448x640 20 persons, 7 handbags, 79.9ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_2.jpg: 384x640 25 persons, 9 cars, 1 bus, 3 trucks, 7 potted plants, 63.3ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_3.jpg: 384x640 3 persons, 1 backpack, 1 skis, 61.9ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_4.jpg: 448x640 16 persons, 1 bicycle, 13 cars, 10 traffic lights, 1 handbag, 1 potted plant, 75.8ms
# Speed: 0.4ms pre-process, 70.2ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/yolov5x_seg

# %%
visualize('runs/predict-seg/yolov5x_seg/')

# %% [markdown]
# ### Using `--retina-masks`

# %%
# !python segment/predict.py --weights yolov5x-seg.pt --source images/ --name yolov5x_seg_retina_masks --exist-ok --retina-masks
# Out:
# segment/predict: weights=['yolov5x-seg.pt'], source=images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=yolov5x_seg_retina_masks, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=True
# YOLOv5 🚀 v7.0-49-g3c1afd9 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
#
# Fusing layers...
# YOLOv5x-seg summary: 455 layers, 88774445 parameters, 0 gradients, 265.7 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_1.jpg: 448x640 20 persons, 7 handbags, 78.1ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_2.jpg: 384x640 25 persons, 9 cars, 1 bus, 3 trucks, 7 potted plants, 61.8ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_3.jpg: 384x640 3 persons, 1 backpack, 1 skis, 60.8ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/Getting_Started_with_Instance_Segmentation/notebooks/yolov5/images/image_4.jpg: 448x640 16 persons, 1 bicycle, 13 cars, 10 traffic lights, 1 handbag, 1 potted plant, 76.8ms
# Speed: 0.6ms pre-process, 69.4ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/yolov5x_seg_retina_masks

# %%
visualize('runs/predict-seg/yolov5x_seg_retina_masks/')

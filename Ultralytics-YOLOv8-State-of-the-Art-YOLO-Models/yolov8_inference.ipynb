# %% [markdown]
# # YOLOv8 Object Detection, Instance Segmentation, and Classification
#
# This notebooks runs inference using the latest YOLOv8 model from Ultralytics. We run inference for three different tasks:
# * Object detection
# * Instance segmentation
# * Image classification
#
# This is the accompanying notebook for the [Ultralytics YOLOv8: State-of-the-Art YOLO Models](https://learnopencv.com/ultralytics-yolov8/) article.

# %%
import matplotlib.pyplot as plt
import os
import glob
import requests
import zipfile

# %% [markdown]
# ## Download Data

# %%
def download_file(url, save_name):
    url = url
    if not os.path.exists(save_name):
        file = requests.get(url)
        open(save_name, 'wb').write(file.content)
        
download_file(
    'https://www.dropbox.com/s/zqgucpnbp6c1uyw/images.zip?dl=1',
    'images.zip'
)

# %%
# Unzip the data file
def unzip(zip_file=None):
    try:
        with zipfile.ZipFile(zip_file) as z:
            z.extractall("./")
            print("Extracted all")
    except:
        print("Invalid file")

unzip('images.zip')
# Out:
# Extracted all

# %% [markdown]
# ## Install Ultralytics Package

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (8.0.0)
# Requirement already satisfied: scipy>=1.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (1.9.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (6.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (1.22.3)
# Requirement already satisfied: GitPython>=3.1.24 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (3.1.29)
# Requirement already satisfied: Pillow>=7.1.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (9.3.0)
# Requirement already satisfied: seaborn>=0.11.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (0.12.1)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (4.7.0.68)
# Requirement already satisfied: ipython in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (8.7.0)
# Requirement already satisfied: tensorboard>=2.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torch>=1.7.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (1.12.0+cu116)
# Requirement already satisfied: requests>=2.23.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: tqdm>=4.64.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: torchvision>=0.8.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (0.13.0+cu116)
# Requirement already satisfied: pandas>=1.1.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (1.5.2)
# Requirement already satisfied: hydra-core>=1.2.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (1.3.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (3.6.2)
# Requirement already satisfied: psutil in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: thop>=0.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from GitPython>=3.1.24->ultralytics) (4.0.10)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from hydra-core>=1.2.0->ultralytics) (4.9.3)
# Requirement already satisfied: omegaconf~=2.2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from hydra-core>=1.2.0->ultralytics) (2.3.0)
# Requirement already satisfied: packaging in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from hydra-core>=1.2.0->ultralytics) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (1.0.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pandas>=1.1.4->ultralytics) (2022.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: absl-py>=0.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (1.3.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (2.2.2)
# Requirement already satisfied: grpcio>=1.24.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (1.51.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (3.20.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (2.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (59.5.0)
# Requirement already satisfied: wheel>=0.26 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from tensorboard>=2.4.1->ultralytics) (0.4.6)
# Requirement already satisfied: typing-extensions in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from torch>=1.7.0->ultralytics) (4.4.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (4.8.0)
# Requirement already satisfied: jedi>=0.16 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (0.18.2)
# Requirement already satisfied: pickleshare in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (0.1.6)
# Requirement already satisfied: decorator in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (5.6.0)
# Requirement already satisfied: stack-data in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (0.6.2)
# Requirement already satisfied: backcall in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from ipython->ultralytics) (0.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1.24->ultralytics) (5.0.0)
# Requirement already satisfied: six>=1.9.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->ultralytics) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from jedi>=0.16->ipython->ultralytics) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->ultralytics) (5.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pexpect>4.3->ipython->ultralytics) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython->ultralytics) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from werkzeug>=0.11.15->tensorboard>=2.4.1->ultralytics) (2.1.1)
# Requirement already satisfied: executing>=1.2.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->ultralytics) (1.2.0)
# Requirement already satisfied: pure-eval in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->ultralytics) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from stack-data->ipython->ultralytics) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.4.1->ultralytics) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/sovit/miniconda3/envs/torch_1_12_0/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->ultralytics) (3.2.2)

# %% [markdown]
# ## Object Detection

# %%
# !yolo task=detect mode=predict model=yolov8x.pt source='images' name=yolov8x_det
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to yolov8x.pt...
# 100%|████████████████████████████████████████| 131M/131M [00:12<00:00, 11.2MB/s]
#
# Fusing layers...
# YOLOv8x summary: 268 layers, 68200608 parameters, 0 gradients, 257.8 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000183.jpg: 640x352 1 dog, 59.9ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000562.jpg: 480x640 2 persons, 1 bicycle, 1 car, 2 backpacks, 68.5ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000880.jpg: 448x640 9 persons, 1 car, 1 truck, 3 horses, 65.8ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_001782.jpg: 480x640 4 persons, 1 sports ball, 1 tennis racket, 68.5ms
# Speed: 0.3ms pre-process, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/yolov8x_det

# %%
# Plot and visualize images in a 2x2 grid.
def visualize(result_dir):
    """
    Function accepts a list of images and plots
    them in a 2x2 grid.
    """
    plt.figure(figsize=(20, 12))
    image_names = glob.glob(os.path.join(result_dir, '*.jpg'))
    for i, image_name in enumerate(image_names):
        image = plt.imread(image_name)
        plt.subplot(2, 2, i+1)
        plt.imshow(image)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
visualize('runs/detect/yolov8x_det/')

# %% [markdown]
# ## Instance Segmentation

# %%
# !yolo task=segment mode=predict model=yolov8x-seg.pt source='images' name=yolov8x_seg
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-seg.pt to yolov8x-seg.pt...
# 100%|████████████████████████████████████████| 137M/137M [00:11<00:00, 12.2MB/s]
#
# Fusing layers...
# YOLOv8x-seg summary: 295 layers, 71797696 parameters, 0 gradients, 344.1 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000183.jpg: 640x352 1 dog, 71.8ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000562.jpg: 480x640 2 persons, 1 bicycle, 1 car, 1 backpack, 83.2ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000880.jpg: 448x640 8 persons, 2 cars, 1 truck, 2 horses, 1 cell phone, 78.2ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_001782.jpg: 480x640 4 persons, 1 sports ball, 1 tennis racket, 82.1ms
# Speed: 0.3ms pre-process, 78.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/yolov8x_seg

# %%
visualize('runs/segment/yolov8x_seg/')

# %% [markdown]
# ## Image Classification

# %%
# !yolo task=classify mode=predict model=yolov8x-cls.pt source='images' name=yolov8x_cls
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.9.15 torch-1.12.0+cu116 CUDA:0 (NVIDIA GeForce GTX 1060, 6078MiB)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-cls.pt to yolov8x-cls.pt...
# 100%|████████████████████████████████████████| 110M/110M [00:20<00:00, 5.52MB/s]
#
# Fusing layers...
# YOLOv8x-cls summary: 133 layers, 57404200 parameters, 0 gradients, 154.8 GFLOPs
# image 1/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000183.jpg: 640x352 n03733805 156.01, n02013706 148.71, n01776313 131.88, n13054560 125.36, n03017168 123.02, 37.7ms
# image 2/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000562.jpg: 480x640 n02988304 239.76, n01776313 231.49, n03272010 229.39, n02013706 212.05, n03733805 205.09, 44.3ms
# image 3/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_000880.jpg: 448x640 n02988304 224.48, n02013706 224.19, n01776313 223.33, n03733805 220.51, n13054560 219.25, 43.1ms
# image 4/4 /media/sovit/hdd1tbinternal/my_data/Data_Science/Big_Vision/my_blogs/20230111_Ultralytics_YOLOv8_State_of_the_Art_YOLO_Models/notebooks/images/2008_001782.jpg: 480x640 n02111500 241.49, n03733805 229.99, n02013706 224.78, n02988304 208.96, n02804610 207.83, 41.7ms
# Speed: 0.9ms pre-process, 41.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/yolov8x_cls

# %%
visualize('runs/classify/yolov8x_cls/')
